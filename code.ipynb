# %%
import pandas
import numpy

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pandas.read_csv('world population data.csv', skiprows=3) # because first 3 rows have no information

# %%
data.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2014         2015         2016         2017  \
# ...

# %%
data.set_index('Country Name', inplace = True)

# %%
data.head()
# Out:
#                             Country Code     Indicator Name Indicator Code  \
# Country Name
# Aruba                                ABW  Population, total    SP.POP.TOTL
# Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# Afghanistan                          AFG  Population, total    SP.POP.TOTL
# Africa Western and Central           AFW  Population, total    SP.POP.TOTL
# Angola                               AGO  Population, total    SP.POP.TOTL
#
#                                     1960         1961         1962  \
# Country Name
# Aruba                            54608.0      55811.0      56682.0
# Africa Eastern and Southern  130692579.0  134169237.0  137835590.0
# Afghanistan                    8622466.0    8790140.0    8969047.0
# Africa Western and Central    97256290.0   99314028.0  101445032.0
# Angola                         5357195.0    5441333.0    5521400.0
#
#                                     1963         1964         1965  \
# ...

# %%
data1 = data.T

# %%
data1.head()
# Out:
# Country Name                Aruba Africa Eastern and Southern  \
# Country Code                  ABW                         AFE
# Indicator Name  Population, total           Population, total
# Indicator Code        SP.POP.TOTL                 SP.POP.TOTL
# 1960                      54608.0                 130692579.0
# 1961                      55811.0                 134169237.0
#
# Country Name          Afghanistan Africa Western and Central  \
# Country Code                  AFG                        AFW
# Indicator Name  Population, total          Population, total
# Indicator Code        SP.POP.TOTL                SP.POP.TOTL
# 1960                    8622466.0                 97256290.0
# 1961                    8790140.0                 99314028.0
#
# Country Name               Angola            Albania            Andorra  \
# Country Code                  AGO                ALB                AND
# Indicator Name  Population, total  Population, total  Population, total
# ...

# %%
data1 = data1.drop('Country Code')
data1 = data1.drop('Indicator Name')
data1 = data1.drop('Indicator Code')
data1 = data1.drop('Unnamed: 67')

# %%
data1.head()
# Out:
# Country Name    Aruba Africa Eastern and Southern Afghanistan  \
# 1960          54608.0                 130692579.0   8622466.0
# 1961          55811.0                 134169237.0   8790140.0
# 1962          56682.0                 137835590.0   8969047.0
# 1963          57475.0                 141630546.0   9157465.0
# 1964          58178.0                 145605995.0   9355514.0
#
# Country Name Africa Western and Central     Angola    Albania  Andorra  \
# 1960                         97256290.0  5357195.0  1608800.0   9443.0
# 1961                         99314028.0  5441333.0  1659800.0  10216.0
# 1962                        101445032.0  5521400.0  1711319.0  11014.0
# 1963                        103667517.0  5599827.0  1762621.0  11839.0
# 1964                        105959979.0  5673199.0  1814135.0  12690.0
#
# Country Name   Arab World United Arab Emirates   Argentina  ...  \
# 1960           93359407.0             133426.0  20349744.0  ...
# ...

# %%
data1.reset_index(inplace=True)

# %%
data1.columns
# Out:
# Index(['index', 'Aruba', 'Africa Eastern and Southern', 'Afghanistan',
#        'Africa Western and Central', 'Angola', 'Albania', 'Andorra',
#        'Arab World', 'United Arab Emirates',
#        ...
#        'Virgin Islands (U.S.)', 'Vietnam', 'Vanuatu', 'World', 'Samoa',
#        'Kosovo', 'Yemen, Rep.', 'South Africa', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='Country Name', length=267)

# %%
data1.head()
# Out:
# Country Name index    Aruba Africa Eastern and Southern Afghanistan  \
# 0             1960  54608.0                 130692579.0   8622466.0
# 1             1961  55811.0                 134169237.0   8790140.0
# 2             1962  56682.0                 137835590.0   8969047.0
# 3             1963  57475.0                 141630546.0   9157465.0
# 4             1964  58178.0                 145605995.0   9355514.0
#
# Country Name Africa Western and Central     Angola    Albania  Andorra  \
# 0                            97256290.0  5357195.0  1608800.0   9443.0
# 1                            99314028.0  5441333.0  1659800.0  10216.0
# 2                           101445032.0  5521400.0  1711319.0  11014.0
# 3                           103667517.0  5599827.0  1762621.0  11839.0
# 4                           105959979.0  5673199.0  1814135.0  12690.0
#
# Country Name   Arab World United Arab Emirates  ... Virgin Islands (U.S.)  \
# ...

# %%
my_year_list = ['1960', '1970','1980','1990','2000','2010','2020']

# %%
data2 = data1[data1['index'].isin(my_year_list)]

# %%
data2.plot.bar(x='index',y='India')
# Out:
# <Axes: xlabel='index'>

# %%
import matplotlib as mp2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
my_year_list = ['1960', '1970','1980','1990','2000','2010','2020']

# %%
data3 = data1[data1['index'].isin(my_year_list)]

# %%
data3.plot.hist(x='index',y='India')
# Out:
# <Axes: ylabel='Frequency'>
